# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
df=pd.DataFrame()
df=pd.read_csv('pro.csv')
df
# Out:
#                                                   url  \
# 0   http://www.imdb.com/movies-coming-soon/2016-09...
# 1   http://www.imdb.com/movies-coming-soon/2016-09...
# 2   http://www.imdb.com/movies-coming-soon/2016-09...
# 3   http://www.imdb.com/movies-coming-soon/2016-09...
# 4   http://www.imdb.com/movies-coming-soon/2016-09...
# 5   http://www.imdb.com/movies-coming-soon/2016-09...
# 6   http://www.imdb.com/movies-coming-soon/2016-09...
# 7   http://www.imdb.com/movies-coming-soon/2016-09...
# 8   http://www.imdb.com/movies-coming-soon/2016-09...
# 9   http://www.imdb.com/movies-coming-soon/2016-09...
# 10  http://www.imdb.com/movies-coming-soon/2016-09...
# 11  http://www.imdb.com/movies-coming-soon/2016-09...
# 12  http://www.imdb.com/movies-coming-soon/2016-09...
# 13  http://www.imdb.com/movies-coming-soon/2016-09...
# 14  http://www.imdb.com/movies-coming-soon/2016-09...
# 15  http://www.imdb.com/movies-coming-soon/2016-09...
# ...

# %%
df.drop('Image', axis=1, inplace=True)
df.drop('Overviewtop link_link', axis=1, inplace=True)
df.drop('Image_link', axis=1, inplace=True)
df.drop('Absmiddle image', axis=1, inplace=True)
df.drop('Director link_link', axis=1, inplace=True)
df.drop('Stars_link', axis=1, inplace=True)
df.drop('Stars (1)_link', axis=1, inplace=True)
df.drop('url', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-d053d4a207ad> in <module>()
# ----> 1 df.drop('Image', axis=1, inplace=True)
#
# /Users/haripadbharti/anaconda/lib/python3.4/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    1595                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1596             else:
# -> 1597                 new_axis = axis.drop(labels, errors=errors)
#    1598             dropped = self.reindex(**{axis_name: new_axis})
#    1599             try:
#
# /Users/haripadbharti/anaconda/lib/python3.4/site-packages/pandas/core/index.py in drop(self, labels, errors)
#    2568         if mask.any():
#    2569             if errors != 'ignore':
# -> 2570                 raise ValueError('labels %s not contained in axis' % labels[mask])
#    2571             indexer = indexer[~mask]
# ...

# %%
df
# Out:
#                                             Image_alt  \
# 0   The Light Between Oceans (2016) Poster; The Li...
# 1   Patient Zero (2016) Poster; Patient Zero (2016...
# 2          Solace (2015) Poster; Solace (2015) Poster
# 3   No manches Frida (2016) Poster; No manches Fri...
# 4            Sully (2016) Poster; Sully (2016) Poster
# 5   Before I Wake (2016) Poster; Before I Wake (20...
# 6        Shut In (2016) Poster; Shut In (2016) Poster
# 7   The Wild Life (2016) Poster; The Wild Life (20...
# 8   Bridget Jones's Baby (2016) Poster; Bridget Jo...
# 9   When the Bough Breaks (2016) Poster; When the ...
# 10       Snowden (2016) Poster; Snowden (2016) Poster
# 11           Nerve (2016) Poster; Nerve (2016) Poster
# 12  The Magnificent Seven (2016) Poster; The Magni...
# 13         Storks (2016) Poster; Storks (2016) Poster
# 14  Queen of Katwe (2016) Poster; Queen of Katwe (...
# 15             Goat (2016) Poster; Goat (2016) Poster
# ...
